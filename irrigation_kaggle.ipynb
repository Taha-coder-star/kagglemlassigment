# %% [markdown]
# # Playground Series S6E4 — Predicting Irrigation Need
# **Multiclass Classification: Low / Medium / High**

# %% [markdown]
# ## 0. Colab Setup
# Run this section only when on Google Colab. It mounts your Drive and sets data paths.

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    # TODO: update this path to wherever you put the folder in your Drive
    BASE = '/content/drive/MyDrive/irrigation-kaggle-assignment'
else:
    BASE = '.'   # local: repo root

DATA_DIR    = f'{BASE}/data'
OUTPUT_DIR  = f'{BASE}/outputs'

print('Base:', BASE)

# %%
# Install any extra packages (Colab already has sklearn, pandas, numpy, matplotlib)
if IN_COLAB:
    # %pip install -q lightgbm xgboost catboost

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings('ignore')

SEED = 42

# %% [markdown]
# ## 2. Load Data

# %%
train = pd.read_csv(f'{DATA_DIR}/train.csv')
test  = pd.read_csv(f'{DATA_DIR}/test.csv')
sub   = pd.read_csv(f'{DATA_DIR}/sample_submission.csv')

print(f'Train: {train.shape}  |  Test: {test.shape}')
train.head()

# %% [markdown]
# ## 3. EDA
# Understand the data before modelling.

# %%
# YOUR CODE HERE
# Suggested checks:
#   train.info()
#   train.describe()
#   train['Irrigation_Need'].value_counts()
#   missing values
#   distribution plots per class

# %% [markdown]
# ## 4. Preprocessing

# %%
TARGET = 'Irrigation_Need'
# Map target to integers (keep consistent order)
label_map  = {'Low': 0, 'Medium': 1, 'High': 2}
inv_map    = {v: k for k, v in label_map.items()}

# YOUR CODE HERE
# Suggested steps:
#   - encode categoricals (LabelEncoder or pd.get_dummies)
#   - split X / y
#   - optional: feature engineering

# %% [markdown]
# ## 5. Model Training

# %%
# YOUR CODE HERE
# Suggested starting point:
#
# from lightgbm import LGBMClassifier
#
# model = LGBMClassifier(
#     class_weight='balanced',   # handles Low/Medium/High imbalance
#     n_estimators=1000,
#     learning_rate=0.05,
#     num_leaves=127,
#     random_state=SEED,
#     device='gpu'               # remove if no GPU
# )
#
# Use StratifiedKFold CV and report macro F1 per fold

# %% [markdown]
# ## 6. Evaluate

# %%
# YOUR CODE HERE
# print(classification_report(y_val, y_pred, target_names=['Low','Medium','High']))
# confusion matrix heatmap

# %% [markdown]
# ## 7. Generate Submission

# %%
# YOUR CODE HERE
# preds = model.predict(X_test)
# sub['Irrigation_Need'] = [inv_map[p] for p in preds]
# sub.to_csv(f'{OUTPUT_DIR}/submission.csv', index=False)
# print('Saved submission.csv')
# sub.head()
